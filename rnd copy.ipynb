# %%
import pandas as pd
import plotly
import plotly.express as px 
import dtale

# %%
pd.set_option('display.max_rows', 50)  # Disable row limit
pd.set_option('display.max_columns', 40)  # Disable column limit
pd.set_option('display.width', 20)  # Disable line width limit
pd.set_option('display.max_colwidth', 100)  # Disable column width limit

# %%
pd.options.plotting.backend = "plotly"
plotly.io.renderers.default = "notebook_connected"

# %%
df = pd.read_json("output/_real-estate-to-rent_apartments-flats__20241207_132732.jsonl", lines=True)
df
# Out:
#                                                                     url  \
# 0     https://www.bazaraki.com/adv/5498789_2-bedroom-apartment-to-rent/
# 1     https://www.bazaraki.com/adv/5136843_3-bedroom-apartment-to-rent/
# 2     https://www.bazaraki.com/adv/5556402_2-bedroom-penthouse-to-rent/
# 3     https://www.bazaraki.com/adv/4817814_3-bedroom-apartment-to-rent/
# 4     https://www.bazaraki.com/adv/5453912_2-bedroom-apartment-to-rent/
# ...                                                                 ...
# 4476  https://www.bazaraki.com/adv/5561352_3-bedroom-apartment-to-rent/
# 4477  https://www.bazaraki.com/adv/5561354_2-bedroom-apartment-to-rent/
# 4478  https://www.bazaraki.com/adv/5515236_2-bedroom-penthouse-to-rent/
# 4479  https://www.bazaraki.com/adv/5561364_2-bedroom-apartment-to-rent/
# 4480  https://www.bazaraki.com/adv/5561357_1-bedroom-penthouse-to-rent/
#
#                             title  \
# 0     2-bedroom apartment to rent
# 1     3-bedroom apartment to rent
# 2     2-bedroom penthouse to rent
# 3     3-bedroom apartment to rent
# 4     2-bedroom apartment to rent
# ...                           ...
# 4476  3-bedroom apartment to rent
# 4477  2-bedroom apartment to rent
# 4478  2-bedroom penthouse to rent
# 4479  2-bedroom apartment to rent
# 4480  1-bedroom penthouse to rent
#
#       price  \
# 0      3100
# 1      1500
# 2       800
# 3      2800
# 4      1900
# ...     ...
# 4476   4500
# 4477   5000
# 4478   2350
# 4479   5800
# 4480   2100
#
#       price_per_sqm  \
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 4476            NaN
# 4477            NaN
# 4478            NaN
# 4479            NaN
# 4480            NaN
#
#                                 location  \
# 0                 Limassol, Agios Tychon
# 1             Larnaca, Larnaka - Sotiros
# 2       Nicosia, Nicosia - Agios Andreas
# 3     Limassol, Germasogeia Tourist Area
# 4          Limassol, Limassol - Kapsalos
# ...                                  ...
# 4476       Limassol, Limassol - Neapolis
# 4477  Limassol, Mouttagiaka Tourist Area
# 4478        Limassol, Limassol - Tsirion
# 4479      Limassol, Potamos Germasogeias
# 4480       Limassol, Limassol - Neapolis
#
#                 posted  \
# 0     03.12.2024 11:01
# 1     03.12.2024 11:19
# 2     03.12.2024 13:30
# 3     29.11.2024 10:14
# 4     29.11.2024 10:22
# ...                ...
# 4476   Yesterday 14:08
# 4477   Yesterday 14:09
# 4478   Yesterday 14:11
# 4479   Yesterday 14:11
# 4480   Yesterday 14:11
#
#         ad_id  \
# 0     5498789
# 1     5136843
# 2     5556402
# 3     4817814
# 4     5453912
# ...       ...
# 4476  5561352
# 4477  5561354
# 4478  5515236
# 4479  5561364
# 4480  5561357
#
#       reference_number  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 4476               NaN
# 4477               NaN
# 4478               NaN
# 4479               NaN
# 4480               NaN
#
#       views  \
# 0       425
# 1       618
# 2       116
# 3       925
# 4       180
# ...     ...
# 4476      8
# 4477      7
# 4478    122
# 4479      8
# 4480     14
#
#             lat  \
# 0     34.732197
# 1     34.918330
# 2     35.166457
# 3           NaN
# 4     34.699894
# ...         ...
# 4476  34.687232
# 4477  34.703480
# 4478  34.696185
# 4479  34.700578
# 4480  34.689471
#
#             lng  \
# 0     33.144681
# 1     33.607264
# 2     33.349762
# 3           NaN
# 4     33.014105
# ...         ...
# 4476  33.057150
# 4477  33.108610
# 4478  33.018832
# 4479  33.089591
# 4480  33.068362
#
#                                                                                               description  \
# 0     Spacious ground-floor apartment located on a hilltop of Agios Tychonas offering breathtaking 180...
# 1     The Flat is the size o 2 x two bedroom flats, converted from construction to 1 BIG 3 bedroom fla...
# 2     The appartment is on the top (fourth) floor of a small building.  It is about a 80 square metres...
# 3     Available from October 2023!\nThis 3 bedroom apartment on the seafront of Limassol is now availa...
# 4     This spacious and luxury 2-bedroom apartment located in the heart of Limassol is now available f...
# ...                                                                                                   ...
# 4476  The premium complex is ideally situated in the vibrant heart of Neapolis, a sought-after area wh...
# 4477  For rent luxurious 2 bedroom apartment in the coastal area. Panoramic windows create a sense of ...
# 4478  Rooftop Luxury 2-Bedroom Apartment in Limassol for rent\nYear of Construction: 2008\nYear of Com...
# 4479  **Modern 2 bedroom apartment in EDEN ROC Block A**\nDeveloper: BBF\n- Wooden flooring\n- Water b...
# 4480  1 bedroom penthouse apartment situated in Neapolis area. Walking distance to the beach. On the 5...
#
#                                                                                                    images  \
# 0     [https://cdn1.bazaraki.com/media/cache1/c9/4e/c94e255b0cac2582a9b63be777871974.webp, https://cdn...
# 1     [https://cdn1.bazaraki.com/media/cache1/10/70/10704f9f5235e8db74841efd335fd5c2.webp, https://cdn...
# 2     [https://cdn1.bazaraki.com/media/cache1/16/51/1651cbc133bfdf1c784722fb58f74d81.webp, https://cdn...
# 3     [https://cdn1.bazaraki.com/media/cache1/5b/9c/5b9c0bed45cf0aecfe8d7d86758c91c6.webp, https://cdn...
# 4     [https://cdn1.bazaraki.com/media/cache1/0d/8f/0d8f4a3c8e2454fb219331dca123d29b.webp, https://cdn...
# ...                                                                                                   ...
# 4476  [https://cdn1.bazaraki.com/media/cache1/c2/2f/c22f9aa309ecce542744c4c57a811f35.webp, https://cdn...
# 4477  [https://cdn1.bazaraki.com/media/cache1/d9/83/d983ede3a1c2bf2e65f1ee312958f9a3.webp, https://cdn...
# 4478  [https://cdn1.bazaraki.com/media/cache1/58/d1/58d1de312b0bdd628fcf82c9c01f214c.webp, https://cdn...
# 4479  [https://cdn1.bazaraki.com/media/cache1/26/b6/26b67227277175802cdb84301f2e5b58.webp, https://cdn...
# 4480  [https://cdn1.bazaraki.com/media/cache1/58/a7/58a7a606b6abc34484014bc1fbfd60f6.webp, https://cdn...
#
#      Property area  \
# 0           100 m²
# 1           180 m²
# 2            80 m²
# 3           120 m²
# 4           102 m²
# ...            ...
# 4476        187 m²
# 4477        112 m²
# 4478        176 m²
# 4479        111 m²
# 4480         50 m²
#
#          Pets  \
# 0     Allowed
# 1     Allowed
# 2     Allowed
# 3         NaN
# 4         NaN
# ...       ...
# 4476      NaN
# 4477      NaN
# 4478  Allowed
# 4479      NaN
# 4480      NaN
#
#            Type  \
# 0     Apartment
# 1     Apartment
# 2     Penthouse
# 3     Apartment
# 4     Apartment
# ...         ...
# 4476  Apartment
# 4477  Apartment
# 4478  Penthouse
# 4479  Apartment
# 4480  Penthouse
#
#               Floor  \
# 0      Ground floor
# 1               3rd
# 2               4th
# 3               4th
# 4               2nd
# ...             ...
# 4476            4th
# 4477  8th and above
# 4478            3rd
# 4479            2nd
# 4480            1st
#
#         Parking  \
# 0       Covered
# 1       Covered
# 2       Covered
# 3     Uncovered
# 4       Covered
# ...         ...
# 4476    Covered
# 4477    Covered
# 4478    Covered
# 4479    Covered
# 4480    Covered
#
#            Furnishing  \
# 0     Fully Furnished
# 1     Fully Furnished
# 2     Fully Furnished
# 3     Fully Furnished
# 4     Fully Furnished
# ...               ...
# 4476  Fully Furnished
# 4477              NaN
# 4478   Semi-Furnished
# 4479  Fully Furnished
# 4480  Fully Furnished
#
#                                                      Included  \
# 0                         Pool, Garden, Balcony, Storage room
# 1                                           Elevator, Balcony
# 2                             Elevator, Balcony, Storage room
# 3                                                         NaN
# 4                                                         NaN
# ...                                                       ...
# 4476                                             Storage room
# 4477     Pool, Storage room, Garden, Alarm, Balcony, Playroom
# 4478                Elevator, Balcony, Playroom, Storage room
# 4479  Pool, Garden, Elevator, Balcony, Playroom, Storage room
# 4480                          Storage room, Elevator, Balcony
#
#      Online viewing  \
# 0                No
# 1               NaN
# 2                No
# 3               NaN
# 4               NaN
# ...             ...
# 4476            NaN
# 4477            NaN
# 4478            NaN
# 4479            NaN
# 4480            NaN
#
#      Air conditioning  \
# 0     Full, all rooms
# 1                 NaN
# 2     Full, all rooms
# 3     Full, all rooms
# 4     Full, all rooms
# ...               ...
# 4476  Full, all rooms
# 4477  Full, all rooms
# 4478  Full, all rooms
# 4479  Full, all rooms
# 4480  Full, all rooms
#
#      Energy Efficiency  \
# 0          In Progress
# 1                   B+
# 2                    C
# 3                  N/A
# 4                  N/A
# ...                ...
# 4476                 A
# 4477                 A
# 4478               N/A
# 4479                 A
# 4480               N/A
#
#      Bedrooms  \
# 0           2
# 1           3
# 2           2
# 3           3
# 4           2
# ...       ...
# 4476        3
# 4477        2
# 4478        2
# 4479        2
# 4480        1
#
#      Bathrooms  \
# 0            2
# 1            2
# 2            1
# 3            3
# 4            2
# ...        ...
# 4476         3
# 4477         2
# 4478         2
# 4479         2
# 4480         1
#
#       Postal code  \
# 0             NaN
# 1          6042.0
# 2          1095.0
# 3             NaN
# 4             NaN
# ...           ...
# 4476          NaN
# 4477       4048.0
# 4478       3080.0
# 4479          NaN
# 4480          NaN
#
#      Construction year  \
# 0                  NaN
# 1                 2018
# 2                 2006
# 3                  NaN
# 4                 2022
# ...                ...
# 4476               NaN
# 4477               NaN
# 4478              2008
# 4479              2022
# 4480               NaN
#
#      Reference number
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3               87285
# 4              101791
# ...               ...
# 4476          1320158
# 4477          1320792
# 4478              NaN
# 4479              NaN
# 4480          1321182
#
# [4481 rows x 28 columns]

# %%
df[["city", "district"]] = df.location.str.split(",", expand=True)

# %%
df.iloc[0].T
# Out:
# url                                                    https://www.bazaraki.com/adv/5498789_2-bedroom-apartment-to-rent/
# title                                                                                        2-bedroom apartment to rent
# price                                                                                                               3100
# price_per_sqm                                                                                                        NaN
# location                                                                                          Limassol, Agios Tychon
# posted                                                                                                  03.12.2024 11:01
# ad_id                                                                                                            5498789
# reference_number                                                                                                     NaN
# views                                                                                                                425
# lat                                                                                                            34.732197
# lng                                                                                                            33.144681
# description          Spacious ground-floor apartment located on a hilltop of Agios Tychonas offering breathtaking 180...
# images               [https://cdn1.bazaraki.com/media/cache1/c9/4e/c94e255b0cac2582a9b63be777871974.webp, https://cdn...
# Property area                                                                                                     100 m²
# Pets                                                                                                             Allowed
# Type                                                                                                           Apartment
# Floor                                                                                                       Ground floor
# Parking                                                                                                          Covered
# Furnishing                                                                                               Fully Furnished
# Included                                                                             Pool, Garden, Balcony, Storage room
# Online viewing                                                                                                        No
# Air conditioning                                                                                         Full, all rooms
# Energy Efficiency                                                                                            In Progress
# Bedrooms                                                                                                               2
# Bathrooms                                                                                                              2
# Postal code                                                                                                          NaN
# Construction year                                                                                                    NaN
# Reference number                                                                                                     NaN
# city                                                                                                            Limassol
# district                                                                                                    Agios Tychon
# Name: 0, dtype: object

# %%
selected_df = saledf[saledf.price < 5000]
print(f"removed {len(saledf) - len(selected_df)} rows")
df = selected_df
# Out:
# removed 12671 rows

# %%
selected_df = df.query("`Bedrooms` in ('3', '2', '1', 'Studio')")
print(f"removed {len(df) - len(selected_df)} rows")
df = selected_df
# Out:
# removed 0 rows

# %%
px.histogram(df.query("city == 'Limassol' and Bedrooms == '1'"), x="price", ).show()
# Out:
# <div>                            <div id="c6185e3f-983b-47bc-b068-118197261b2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6185e3f-983b-47bc-b068-118197261b2b")) {                    Plotly.newPlot(                        "c6185e3f-983b-47bc-b068-118197261b2b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"price=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[700,650,1100,1600,1750,1100,1850,1400,1700,900,1100,1400,1300,1400,1200,1450,900,1100,1200,1700,1500,1350,2350,1150,1000,1000,2200,1550,1050,1050,725,6500,800,1800,2000,2200,2100,7000,2000,1000,1300,3750,1550,1500,1300,1200,1450,1000,1300,1800,1500,1650,1050,1000,1550,1000,1800,1300,1400,1150,2000,1000,1300,1500,1600,1200,1650,875,1750,1050,1350,1800,1450,1400,1600,2100,2000,2500,5500,1430,1100,850,6000,1550,1300,1550,1600,1600,1000,950,1350,850,800,1200,1500,1250,1500,1100,1200,1350,1100,1500,1300,730,1600,1050,1058,1200,1150,1250,1300,1100,900,1300,1200,1050,1000,2350,7000,1500,1100,1550,6500,900,1200,1650,900,1600,1000,900,2200,1000,1300,800,1400,1800,1600,1350,900,1050,1200,1800,2500,1000,1550,1255,990,1500,1400,1500,1500,1400,1700,1500,1600,1800,1200,1600,1500,1300,860,1200,1550,1350,1300,1700,1500,1900,3680,1200,1200,6400,900,780,2500,1800,2200,1250,900,3680,1500,1150,900,1350,1850,1200,3200,800,1900,1300,1600,1750,820,370,3900,3900,1200,1200,3000,1200,1000,2500,1450,1100,1100,1150,1600,1350,1050,1100,1500,1300,1100,1300,1650,1500,1200,1000,1600,1550,2000,1600,1250,900,1500,1600,1300,1600,1400,980,2000,2000,1250,1000,1500,1250,1400,1750,1600,1100,1200,1100,740,1200,2400,1600,1250,1250,1100,1250,1150,1550,1200,1250,1100,1400,1800,1300,1200,1600,1200,3680,1100,3500,1300,1400,1600,1400,900,1500,1300,1400,1950,1300,1000,1250,1150,1350,2350,6400,1200,1100,1600,1000,1500,1100,1250,775,2550,1400,1300,1200,2050,1255,1545,1518,1200,1349,1255,1390,1450,1500,1200,1010,1200,1200,1400,1050,1150,1350,950,1200,2200,1450,800,4400,1150,1200,1300,1500,1800,1600,1300,1200,700,1200,1300,1300,1550,1550,1350,1000,1400,1300,1200,1250,1300,2100],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555555 ...

# %%
px.histogram(df, x="price", barmode='overlay', facet_col="city", color="Bedrooms").show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="b46da0f0-9954-4641-b6ba-37848bd9ff61" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b46da0f0-9954-4641-b6ba-37848bd9ff61")) {                    Plotly.newPlot(                        "b46da0f0-9954-4641-b6ba-37848bd9ff61",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Bedrooms=2\u003cbr\u003ecity=Limassol\u003cbr\u003eprice=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"2","offsetgroup":"2","orientation":"v","showlegend":true,"x":[3100,1900,2500,2300,1350,1700,2300,2800,2200,1650,1650,1700,1550,2100,8000,2400,1950,1800,3000,1300,2350,1700,1250,1350,3900,1700,7200,550,4000,1800,1000,1800,4200,6000,1700,1450,3200,1600,1500,1200,1700,1699,1850,700,7200,1700,1300,1500,2100,1400,2000,1750,1250,3000,1900,2800,5500,3200,1800,8000,2800,1000,2250,1600,2150,1650,1300,2500,1400,1650,1150,4200,1600,8000,1950,5900,6000,4200,2500,2400,1800,1500,7900,1800,1500,2750,1700,2000,1700,1700,2000,2000,1900,1000,1700,1850,1700,1250,2000,2400,1000,2200,1750,2750,1600,3000,1800,1500,2000,3000,1300,1500,1300,2800,1700,1500,800,1800,1450,1350,2100,1600,2000,2500,1450,1600,3500,4500,2500,8000,1100,1500,1700,1500,1300,8000,1900,2000,2000,1400,1600,1900,1700,1000,1900,4500,2100,1500,1500,1300,1500,1700,2300,1200,1000,2400,1350,1300,2300,8000,1800,2000,3150,4200,3200,2000,2000,1600,4500,2300,4700,1800,1800,1500,1700,1400,1300,1800,1400,1600,2500,2500,7000,1300,2200,2000,3100,2400,8000,1800,2000,3500,1400,1455,1600,1436,5727,1982,1500,2000,1200,1300,2300,1200,2500,2500,2300,2000,2000,2200,2500,2300,2000,5300,2800,1700,1900,1600,2400,6400,14000,1300,2000,7500,2100,2500,2500,2400,2800,2690,1800,2300,2400,2300,1350,2000,3100,1800,2300,1500,1300,1100,6000,1500,1700,5500,2350,1600,1450,1200,2500,1500,1400,1480,1250,2700,1100,1500,2800,1500,2000,1250,2000,1900,12000,1700,1800,2500,2300,1600,1500,1300,1300,2500,1900,2000,1600,2300,1500,1400,1500,1900,6500,2400,6500,1350,2800,1700,2500,2000,1800,1650,1200,2400,1800,1550,2000,1300,1600,1400,4000,1500,1800,2200,1800,1300,6500,2000,2200,1800,1400,2000,1500,1900,1200,1200,1700,12500,1800,1350,2350,2500,1950,1200,1600,1900,2000,3000,1600,1300,1800,1500,1200,2000,2200,2600,6700,3000,1300,2000,1400,2000,1500,2100,1800,7000,1600,1800,1850,2400,1800,1300,2700,2200,2200,2500,1700,1600,1490,1300,1850,2800,1850,2000,2700,1550,11000,1000,2100,950,7500,1250,1800,1850,2200,2500,1200,3500,2500,2300,3500,3000,2000,1850,1800,2800,1600,1950,2000,2300,1250,2700,1500,1600,2400,1850,1250,3500,1550,1800,2500,2500,1600,2500,1650,8000,2000,4500,2200,1100,1600,1900,1600,2200,2550,1800,1300,2700,1700,2800,1200,1100,2740,3200,2000,8000,1000,1500,8000,6000,1500,1400,1800,1850,3500,2000,2000,1800,1500,1400,1650,2000,1800,1800,1900,2350,1400,2200,2400,1700,2500,2300,10500,1100,15000,1800,2200,1900,1600,1800,1500,2300,2500,1900,1700,2500,2350,1600,2000,1500,2200,2100,2000,1800,6000,2000,1500,1900,1200,2000,2400,2300,2200,2000,1250,2500,1400,1750,1500,1600,770,1200,1100,2150,2000,2700,2500,1950,1350,1350,1800,1600,1300,1900,3000,2600,2200,2000,1700,4200,5500,11000,2800,1325,2350,1350,2800,1600,2000,1500,2600,2500,1200,1200,2600,1100,2500,1800,2200,2600,1300,2700,3000,4000,2500,2400,1300,2200,2500,1100,1900,1200,2250,2200,2400,12000,1500,1500,1700,1500,1100,2400,1150,1600,1600,1800,1500,2100,3000,1800,2400,1200,1500,2250,2100,2500,2500,2600,1700,1700,1300,2500,2200,3400,2000,2200,2600,2000,2500,2300,2000,3100,1550,1500,1800,2500,1750,2300,1500,2800,2700,1700,1700,2700,3000,2200,8000,10000,1450,2950,2700,1350,4000,2200,1400,2800,1200,900,1400,2000,1700,2000,1699,1150,1100,2400,2300,1800,4500,2200,2000,3000,1600,2700,1800,200 ...

# %%
saledf = pd.read_json("output/_real-estate-for-sale_apartments-flats__20241207_133456.jsonl", lines=True)
saledf
# Out:
#                                                                       url  \
# 0      https://www.bazaraki.com/adv/5270074_1-bedroom-apartment-for-sale/
# 1      https://www.bazaraki.com/adv/5513457_3-bedroom-penthouse-for-sale/
# 2      https://www.bazaraki.com/adv/5225611_3-bedroom-apartment-for-sale/
# 3         https://www.bazaraki.com/adv/5294642_studio-apartment-for-sale/
# 4      https://www.bazaraki.com/adv/5556626_2-bedroom-apartment-for-sale/
# ...                                                                   ...
# 12666  https://www.bazaraki.com/adv/5513325_1-bedroom-apartment-for-sale/
# 12667  https://www.bazaraki.com/adv/5493768_2-bedroom-apartment-for-sale/
# 12668  https://www.bazaraki.com/adv/5194691_3-bedroom-penthouse-for-sale/
# 12669  https://www.bazaraki.com/adv/5549570_1-bedroom-apartment-for-sale/
# 12670  https://www.bazaraki.com/adv/5425123_2-bedroom-apartment-for-sale/
#
#                               title  \
# 0      1-bedroom apartment fоr sаle
# 1      3-bedroom penthouse fоr sаle
# 2      3-bedroom apartment fоr sаle
# 3         Studio apartment fоr sаle
# 4      2-bedroom apartment fоr sаle
# ...                             ...
# 12666  1-bedroom apartment fоr sаle
# 12667  2-bedroom apartment fоr sаle
# 12668  3-bedroom penthouse fоr sаle
# 12669  1-bedroom apartment fоr sаle
# 12670  2-bedroom apartment fоr sаle
#
#         price  \
# 0      110000
# 1      550000
# 2      600000
# 3      197000
# 4      169500
# ...       ...
# 12666  252000
# 12667  215000
# 12668  420000
# 12669  149000
# 12670  215000
#
#        price_per_sqm  \
# 0             2558.0
# 1             4583.0
# 2             5085.0
# 3             6567.0
# 4             1863.0
# ...              ...
# 12666         4000.0
# 12667         2312.0
# 12668         2819.0
# 12669         3725.0
# 12670         3583.0
#
#                             location  \
# 0                Famagusta, Kapparis
# 1         Limassol, Agios Athanasios
# 2      Limassol, Limassol - Neapolis
# 3        Limassol, Historical Center
# 4                 Paphos, Geroskipou
# ...                              ...
# 12666     Paphos, Tombs Of the Kings
# 12667          Nicosia, Stelmek Area
# 12668     Paphos, Paphos - Moutallos
# 12669     Paphos, Tombs Of the Kings
# 12670            Famagusta, Kapparis
#
#                  posted  \
# 0       Yesterday 16:43
# 1      03.12.2024 23:05
# 2       Yesterday 16:42
# 3      04.12.2024 08:43
# 4      03.12.2024 15:01
# ...                 ...
# 12666  27.11.2024 19:35
# 12667  28.11.2024 10:00
# 12668  28.11.2024 10:56
# 12669  28.11.2024 11:18
# 12670  28.11.2024 11:29
#
#          ad_id  \
# 0      5270074
# 1      5513457
# 2      5225611
# 3      5294642
# 4      5556626
# ...        ...
# 12666  5513325
# 12667  5493768
# 12668  5194691
# 12669  5549570
# 12670  5425123
#
#        reference_number  \
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 12666               NaN
# 12667               NaN
# 12668               NaN
# 12669               NaN
# 12670               NaN
#
#        views  \
# 0       1313
# 1          5
# 2         23
# 3          7
# 4         37
# ...      ...
# 12666     68
# 12667    363
# 12668    380
# 12669    110
# 12670    277
#
#              lat  \
# 0            NaN
# 1            NaN
# 2      34.684042
# 3      34.679846
# 4      34.761539
# ...          ...
# 12666  34.774553
# 12667  35.140516
# 12668        NaN
# 12669  34.774149
# 12670  35.051439
#
#              lng  \
# 0            NaN
# 1            NaN
# 2      33.031313
# 3      33.044669
# 4      32.458060
# ...          ...
# 12666  32.404895
# 12667  33.300250
# 12668        NaN
# 12669  32.406853
# 12670  34.010004
#
#                                                                                                description  \
# 0      A 1-bedroom Second Floor Apartment in Kapparis, Famagusta. The Apartment is located at the top f...
# 1      Reference ID: #SA34867Price details: €550,000 +VATA new project for a three-floor residential bu...
# 2      Luxury Sea view apartment, with panoramic sea views, within walking distance to the beach and th...
# 3      This project features 25 serviced studio apartments located in Limassol's Old Town.\nAmenities i...
# 4      This spacious first floor fully furnished apartment is in a popular complex overlooking a large ...
# ...                                                                                                    ...
# 12666  YL Luxury Homes Ltd presents a new luxury and modern development in the heart of Kato Pafos, clo...
# 12667  Modern Living in Stelmek, Nicosia – Limited Apartments Available!\nBe part of this exciting new ...
# 12668  Location: Center of Paphos in a very quiet area.\nSea view from all apartments.\nGreen space (pa...
# 12669  One bedrooms apartment in Tombs of the Kings area of Paphos District.\nThe property is situated ...
# 12670  Discover the perfect retreat in this modern 2-bedroom apartment located in the heart of the Kapp...
#
#                                                                                                     images  \
# 0      [https://cdn1.bazaraki.com/media/cache1/16/41/1641c407b2fd66410b3a69c9c71fcfc4.webp, https://cdn...
# 1      [https://cdn1.bazaraki.com/media/cache1/e7/b0/e7b0e9e3b0ffc1ead147229f44bafbcd.webp, https://cdn...
# 2      [https://cdn1.bazaraki.com/media/cache1/84/2f/842f66392ea01b68c17398a3b9967564.webp, https://cdn...
# 3      [https://cdn1.bazaraki.com/media/cache1/0f/d6/0fd68165844de93bfca2214d0604c3e5.webp, https://cdn...
# 4      [https://cdn1.bazaraki.com/media/cache1/a3/bc/a3bc868e178410266c6a166a70084d4b.webp, https://cdn...
# ...                                                                                                    ...
# 12666  [https://cdn1.bazaraki.com/media/cache1/a5/f2/a5f2df0c92055456183edc04b3265cbd.webp, https://cdn...
# 12667  [https://cdn1.bazaraki.com/media/cache1/85/de/85de8c5d2727aef312fc7f49a7b028ca.webp, https://cdn...
# 12668  [https://cdn1.bazaraki.com/media/cache1/c1/92/c19232e43bbb94dadadb339b74a79a69.webp, https://cdn...
# 12669  [https://cdn1.bazaraki.com/media/cache1/fd/27/fd2729a3188dfe1cdcc1663087b1ff36.webp, https://cdn...
# 12670  [https://cdn1.bazaraki.com/media/cache1/2a/af/2aaf1182e1f3087c366bb24bb298c9b1.webp, https://cdn...
#
#       Property area  \
# 0             43 m²
# 1            120 m²
# 2            118 m²
# 3             30 m²
# 4             91 m²
# ...             ...
# 12666         63 m²
# 12667         93 m²
# 12668        149 m²
# 12669         40 m²
# 12670         60 m²
#
#             Type  \
# 0      Apartment
# 1      Penthouse
# 2      Apartment
# 3      Apartment
# 4      Apartment
# ...          ...
# 12666  Apartment
# 12667  Apartment
# 12668  Penthouse
# 12669  Apartment
# 12670  Apartment
#
#               Floor  \
# 0               2nd
# 1               3rd
# 2               NaN
# 3               3rd
# 4               NaN
# ...             ...
# 12666           1st
# 12667           NaN
# 12668           3rd
# 12669  Ground floor
# 12670           NaN
#
#          Parking  \
# 0        Covered
# 1        Covered
# 2             No
# 3             No
# 4            NaN
# ...          ...
# 12666    Covered
# 12667    Covered
# 12668    Covered
# 12669        NaN
# 12670  Uncovered
#
#                 Condition  \
# 0                  Resale
# 1               Brand new
# 2                  Resale
# 3               Brand new
# 4                  Resale
# ...                   ...
# 12666  Under construction
# 12667           Brand new
# 12668           Brand new
# 12669              Resale
# 12670              Resale
#
#             Furnishing  \
# 0      Fully Furnished
# 1          Unfurnished
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 12666              NaN
# 12667              NaN
# 12668              NaN
# 12669  Fully Furnished
# 12670  Fully Furnished
#
#                                       Included  \
# 0                  Pool, Balcony, Storage room
# 1                        Storage room, Balcony
# 2                                          NaN
# 3                                     Elevator
# 4                                          NaN
# ...                                        ...
# 12666    Pool, Elevator, Balcony, Storage room
# 12667  Garden, Elevator, Balcony, Storage room
# 12668          Elevator, Balcony, Storage room
# 12669                                      NaN
# 12670                       Pool, Storage room
#
#       Air conditioning  \
# 0      Full, all rooms
# 1                   No
# 2                  NaN
# 3      Full, all rooms
# 4                  NaN
# ...                ...
# 12666              NaN
# 12667              NaN
# 12668  Full, all rooms
# 12669              NaN
# 12670  Full, all rooms
#
#       Energy Efficiency  \
# 0                   N/A
# 1                   N/A
# 2                    B+
# 3                     A
# 4                   N/A
# ...                 ...
# 12666                 A
# 12667                 A
# 12668                 A
# 12669               N/A
# 12670                 A
#
#       Bedrooms  \
# 0            1
# 1            3
# 2            3
# 3       Studio
# 4            2
# ...        ...
# 12666        1
# 12667        2
# 12668        3
# 12669        1
# 12670        2
#
#       Square meter price  \
# 0             €2.558 /m²
# 1             €4.583 /m²
# 2             €5.085 /m²
# 3             €6.567 /m²
# 4             €1.863 /m²
# ...                  ...
# 12666         €4.000 /m²
# 12667         €2.312 /m²
# 12668         €2.819 /m²
# 12669         €3.725 /m²
# 12670         €3.583 /m²
#
#       Bathrooms  \
# 0             1
# 1             2
# 2             4
# 3           NaN
# 4             1
# ...         ...
# 12666         1
# 12667         2
# 12668         2
# 12669         1
# 12670         1
#
#       Reference number  \
# 0                  NaN
# 1              SA34867
# 2                 7444
# 3                52865
# 4              MDVGPH2
# ...                ...
# 12666              NaN
# 12667              NaN
# 12668          CS14322
# 12669          CS15056
# 12670             2722
#
#        Postal code  \
# 0              NaN
# 1              NaN
# 2           3030.0
# 3              NaN
# 4              NaN
# ...            ...
# 12666          NaN
# 12667       2335.0
# 12668          NaN
# 12669          NaN
# 12670          NaN
#
#       Construction year  \
# 0                   NaN
# 1                   NaN
# 2                  2023
# 3                   NaN
# 4                   NaN
# ...                 ...
# 12666               NaN
# 12667              2024
# 12668              2023
# 12669               NaN
# 12670               NaN
#
#       Online viewing  \
# 0                NaN
# 1                NaN
# 2                NaN
# 3                 No
# 4                NaN
# ...              ...
# 12666            NaN
# 12667            NaN
# 12668            NaN
# 12669            NaN
# 12670             No
#
#        Registration block  \
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 12666                 NaN
# 12667                 NaN
# 12668                 NaN
# 12669                 NaN
# 12670                 NaN
#
#        Registration number
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 12666                  NaN
# 12667                  NaN
# 12668                  NaN
# 12669                  NaN
# 12670                  NaN
#
# [12671 rows x 31 columns]

# %%
saledf.iloc[0].T
# Out:
# url                                                     https://www.bazaraki.com/adv/5270074_1-bedroom-apartment-for-sale/
# title                                                                                         1-bedroom apartment fоr sаle
# price                                                                                                               110000
# price_per_sqm                                                                                                       2558.0
# location                                                                                               Famagusta, Kapparis
# posted                                                                                                     Yesterday 16:43
# ad_id                                                                                                              5270074
# reference_number                                                                                                       NaN
# views                                                                                                                 1313
# lat                                                                                                                    NaN
# lng                                                                                                                    NaN
# description            A 1-bedroom Second Floor Apartment in Kapparis, Famagusta. The Apartment is located at the top f...
# images                 [https://cdn1.bazaraki.com/media/cache1/16/41/1641c407b2fd66410b3a69c9c71fcfc4.webp, https://cdn...
# Property area                                                                                                        43 m²
# Type                                                                                                             Apartment
# Floor                                                                                                                  2nd
# Parking                                                                                                            Covered
# Condition                                                                                                           Resale
# Furnishing                                                                                                 Fully Furnished
# Included                                                                                       Pool, Balcony, Storage room
# Air conditioning                                                                                           Full, all rooms
# Energy Efficiency                                                                                                      N/A
# Bedrooms                                                                                                                 1
# Square meter price                                                                                              €2.558 /m²
# Bathrooms                                                                                                                1
# Reference number                                                                                                       NaN
# Postal code                                                                                                            NaN
# Construction year                                                                                                      NaN
# Online viewing                                                                                                         NaN
# Registration block                                                                                                     NaN
# Registration number                                                                                                    NaN
# Name: 0, dtype: object

# %%
saledf[["city", "district"]] = saledf.location.str.split(",", expand=True)
